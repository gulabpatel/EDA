# %% [markdown]
# <a href="https://colab.research.google.com/github/gulabpatel/EDA/blob/main/04.1%3A%20Dtreeviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# %%
df = pd.read_csv("https://raw.githubusercontent.com/bhattbhavesh91/multivariate-adaptive-regression-splines-demo/main/Data.csv")
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X = df[["TV", "radio", "newspaper"]]
y = df["sales"]

regressor = DecisionTreeRegressor(random_state = 2022, max_depth=3)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=2022)

# %%
from sklearn import tree
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(regressor,
                   feature_names = ["TV", "radio", "newspaper"],
                   class_names = "sales",
                   filled=True)

# %%
# !pip install -q dtreeviz
# Out:
#      |████████████████████████████████| 61 kB 749 bytes/s
#   Building wheel for dtreeviz (setup.py) ... done

# %%
from dtreeviz.trees import *

viz = dtreeviz(regressor,
               X,
               y,
               target_name='sales',
               feature_names=["TV", "radio", "newspaper"])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
viz
